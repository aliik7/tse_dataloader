# %%
from tse_dataloader import download, analysis, stock_list

# %%
melt= download.get_data('وبملت')
melt
# Out:
#                    TICKER    FIRST     HIGH      LOW    CLOSE          VALUE  \
# Date
# 2009-02-18  S*Mellat.Bank   1050.0   1050.0   1050.0   1050.0   347393807250
# 2009-02-21  S*Mellat.Bank   1051.0   1076.0   1042.0   1050.0   352194689892
# 2009-02-22  S*Mellat.Bank   1065.0   1074.0   1055.0   1065.0     8981292784
# 2009-02-23  S*Mellat.Bank   1066.0   1067.0   1059.0   1061.0     9090532333
# 2009-02-25  S*Mellat.Bank   1061.0   1064.0   1050.0   1058.0     7863032258
# ...                   ...      ...      ...      ...      ...            ...
# 2020-07-05  S*Mellat.Bank  24560.0  27040.0  24480.0  25670.0  5766735541640
# 2020-07-06  S*Mellat.Bank  26200.0  26950.0  26200.0  26860.0  6812022224090
# 2020-07-07  S*Mellat.Bank  27320.0  28200.0  25910.0  26680.0  5144010893190
# 2020-07-08  S*Mellat.Bank  26000.0  28010.0  25350.0  25480.0  5339166341140
# 2020-07-11  S*Mellat.Bank  24210.0  26750.0  24210.0  24590.0  5501799835400
#
# ...

# %%
shst= download.getcode_data(2400322364771558)
shst.head()
# Out:
#                     TICKER   FIRST    HIGH     LOW   CLOSE           VALUE  \
# Date
# 2020-04-15  Social.Sec.Inv  8600.0  8600.0  8600.0  8600.0  57619891863600
# 2020-04-18  Social.Sec.Inv  9030.0  9030.0  9030.0  8889.0     84687412530
# 2020-04-19  Social.Sec.Inv  9333.0  9333.0  9333.0  9027.0     40548235797
# 2020-04-20  Social.Sec.Inv  9478.0  9478.0  9478.0  9269.0     71072242612
# 2020-04-21  Social.Sec.Inv  9732.0  9732.0  9732.0  9483.0     62696434404
#
#                    VOL  OPENINT PER    OPEN    LAST date_shamsi
# Date
# 2020-04-15  6699987426  2061657   D  1000.0  8600.0  1399/01/27
# 2020-04-18     9378451     2122   D  8600.0  9030.0  1399/01/30
# 2020-04-19     4344609     2796   D  8889.0  9333.0  1399/01/31
# 2020-04-20     7498654     3759   D  9027.0  9478.0  1399/02/01
# 2020-04-21     6442297     3290   D  9269.0  9732.0  1399/02/02

# %%
melt= melt.loc['2019-04-30':'2020-07-15']
melt
# Out:
#                    TICKER    FIRST     HIGH      LOW    CLOSE          VALUE  \
# Date
# 2019-04-30  S*Mellat.Bank   3400.0   3416.0   3250.0   3314.0   332138742912
# 2019-05-01  S*Mellat.Bank   3267.0   3470.0   3267.0   3411.0   364355770482
# 2019-05-04  S*Mellat.Bank   3420.0   3581.0   3420.0   3568.0   502829361977
# 2019-05-05  S*Mellat.Bank   3698.0   3746.0   3501.0   3702.0   720415047516
# 2019-05-06  S*Mellat.Bank   3610.0   3679.0   3517.0   3547.0   248469287463
# ...                   ...      ...      ...      ...      ...            ...
# 2020-07-05  S*Mellat.Bank  24560.0  27040.0  24480.0  25670.0  5766735541640
# 2020-07-06  S*Mellat.Bank  26200.0  26950.0  26200.0  26860.0  6812022224090
# 2020-07-07  S*Mellat.Bank  27320.0  28200.0  25910.0  26680.0  5144010893190
# 2020-07-08  S*Mellat.Bank  26000.0  28010.0  25350.0  25480.0  5339166341140
# 2020-07-11  S*Mellat.Bank  24210.0  26750.0  24210.0  24590.0  5501799835400
#
# ...

# %%
analysis.close_vol(melt)

# %%
analysis.sma(melt, 20, 50)

# %%
analysis.ema(melt.reset_index(), 20, 50)

# %%
analysis.return_dev(melt)

# %%
stock_list.add(2400322364771558, 'شستا')
# Out:
# Symbol added to the list!
